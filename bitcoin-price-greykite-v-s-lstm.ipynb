# %% [markdown]
# <br>
# <h1 style = "font-size:35px; font-family:cursive ; font-weight : bold; color : #650076; text-align: center;">💲📈 Bitcoin Price Prediction : GreyKite V/s LSTM </h1>
# <br>

# %% [markdown]
# ![](https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fspecials-images.forbesimg.com%2Fdam%2Fimageserve%2F908633080%2F960x0.jpg%3Ffit%3Dscale)

# %% [markdown]
# # **Context**
# <p style="font-size:15px;color:#1C37A6;">Bitcoin (₿) is a decentralized digital currency, without a central bank or single administrator, that can be sent from user to user on the peer-to-peer bitcoin network without the need for intermediaries. Transactions are verified by network nodes through cryptography and recorded in a public distributed ledger called a blockchain. The cryptocurrency was invented in 2008 by an unknown person or group of people using the name Satoshi Nakamoto. The currency began use in 2009 when its implementation was released as open-source software.<br><br>
# Accurate knowledge about the future is helpful to any business. Time series forecasts can provide future expectations for metrics and other quantities that are measurable over time.<br>
# While domain knowledge and expert judgment can sometimes produce accurate forecasts, algorithmic automation enables scalability and reproducibility, and may improve accuracy. Algorithmic forecasts can be consumed by additional algorithms downstream to make decisions or derive insights.</p>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bitcoin-historical-data/bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv

# %%
from IPython.display import HTML
HTML("""
<style>
h1,h2,h3 {
	margin: 1em 0 0.5em 0;
	font-weight: 600;
	font-family: 'Titillium Web', sans-serif;
	position: relative;  
	font-size: 36px;
	line-height: 40px;
	padding: 15px 15px 15px 2.5%;
	color: #13003A;
	box-shadow: 
		inset 0 0 0 1px rgba(53,86,129, 1), 
		inset 0 0 5px rgba(53,86,129, 1),
		inset -285px 0 35px white;
	border-radius: 0 10px 0 15px;
	background: #fff
    
}
</style>
""")
# Out:
# <style>
# h1,h2,h3 {
# 	margin: 1em 0 0.5em 0;
# 	font-weight: 600;
# 	font-family: 'Titillium Web', sans-serif;
# 	position: relative;
# 	font-size: 36px;
# 	line-height: 40px;
# 	padding: 15px 15px 15px 2.5%;
# 	color: #13003A;
# 	box-shadow:
# 		inset 0 0 0 1px rgba(53,86,129, 1),
# 		inset 0 0 5px rgba(53,86,129, 1),
# 		inset -285px 0 35px white;
# 	border-radius: 0 10px 0 15px;
# 	background: #fff
#
# }
# </style>

# %% [markdown]
# <h1 style="background-color:#88FBFF;font-size:30px;color:#00033E;font-weight : bold">Introduction to GreyKite :</h1>

# %% [markdown]
# ![](https://content.linkedin.com/content/dam/engineering/site-assets/images/blog/posts/2021/05/greykite1.png)

# %% [markdown]
# <p style="font-size:15px;color:#1C37A6;">This brand new Python library <b>GreyKite by Linkedin</b>, is used for time series forecasting. This library makes the life of data scientists easier.
#     Its main forecasting algorithm, called <b>Silverkite</b>, is fast, accurate, and intuitive, making it suitable for interactive and automated forecasting at scale. We will start by describing a few applications and then walk through the algorithm design and user experience.</p>

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold">Tech behind GreyKite :</h1>

# %% [markdown]
# ![](https://analyticsdrift.com/wp-content/uploads/2021/05/LinkedIn-greykite-architecture-1024x481.png)

# %% [markdown]
# <p style="font-size:15px;color:#1C37A6;"><b>Greykite</b> contains a simple modeling interface that facilitates data exploration and model tuning. The library provides intuitive forecasts through its flagship algorithm, known as Silverkite. <b>Silverkite</b> is highly customizable and includes tuning parameters to capture diverse time series characteristics.
#     Besides Silverkite, Greykite also supports <b>Prophet</b>, which is an open-source algorithm for forecasting time series data. The Prophet algorithm is developed by Facebook and is robust to missing data and shifts in the trend and handles outliers well.</p>

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold">Features of GreyKite :</h1>

# %% [markdown]
# - **Fast training and scoring**
# Works with intelligent prototyping, framework search, and benchmarking. Matrix search is valuable for model choice and self-loader estimating of different measurements.
# - **Flexible design**
# Gives time arrangement regressors to catch pattern, irregularity, occasions, changepoints, and autoregression, and allows you to add your own.<br>
# Fits the conjecture utilizing an AI model.
# - **Intuitive Interface**
# Gives incredible plotting apparatuses to investigate irregularity, connections, changepoints, and so forth <br>
# Gives model formats (default boundaries) that function admirably dependent on information attributes and gauge prerequisites (for example every day long haul conjecture).<br>
# Produces interpretable yield, with model rundown to analyze individual regressors, and segment plots to outwardly review the consolidated impact of related regressors <br>
# - **Extensible Framework**
# Uncovered numerous estimate calculations in a similar interface, making it simple to attempt calculations from various libraries and think about outcomes.<br>
# A similar pipeline gives preprocessing, cross-approval, backtest, estimate, and assessment with any calculation.

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold">⚙ Installation :</h1>

# %%
# !pip install greykite
# Out:
# Collecting greykite
#   Downloading greykite-0.1.1-py2.py3-none-any.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 43 kB/s
# Collecting pandas==1.1.3
#   Downloading pandas-1.1.3-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 11.6 MB/s
# Collecting ipython==7.1.1
#   Downloading ipython-7.1.1-py3-none-any.whl (764 kB)
#      |████████████████████████████████| 764 kB 13.6 MB/s
# Collecting fbprophet==0.5
#   Downloading fbprophet-0.5.tar.gz (49 kB)
#      |████████████████████████████████| 49 kB 3.8 MB/s
# Collecting seaborn==0.9.0
#   Downloading seaborn-0.9.0-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 13.9 MB/s
# Collecting jupyter-console==6.
#   Downloading jupyter_console-6.0.0-py2.py3-none-any.whl (21 kB)
# Collecting pystan==2.18.0.0
#   Downloading pystan-2.18.0.0-cp37-cp37m-manylinux1_x86_64.whl (50.0 MB)
#      |████████████████████████████████| 50.0 MB 19.8 MB/s
# Requirement already satisfied: matplotlib==3.4.1 in /opt/conda/lib/python3.7/site-packages (from greykite) (3.4.1)
# Collecting holidays==0.9.10
#   Downloading holidays-0.9.10.tar.gz (73 kB)
#      |████████████████████████████████| 73 kB 1.3 MB/s
# Collecting jupyter-client==6.1.5
#   Downloading jupyter_client-6.1.5-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 31.4 MB/s
# Collecting Pillow==8.0.1
#   Downloading Pillow-8.0.1-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 22.7 MB/s
# Requirement already satisfied: scipy==1.5.4 in /opt/conda/lib/python3.7/site-packages (from greykite) (1.5.4)
# Collecting plotly==3.10.0
#   Downloading plotly-3.10.0-py2.py3-none-any.whl (41.5 MB)
#      |████████████████████████████████| 41.5 MB 18.7 MB/s
# Collecting jupyter==1.0.0
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting osqp==0.6.1
#   Downloading osqp-0.6.1-cp37-cp37m-manylinux2010_x86_64.whl (211 kB)
#      |████████████████████████████████| 211 kB 26.6 MB/s
# Collecting ipykernel==4.8.2
#   Downloading ipykernel-4.8.2-py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 29.0 MB/s
# Collecting testfixtures==6.14.2
#   Downloading testfixtures-6.14.2-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 5.4 MB/s
# Collecting tqdm==4.52.0
#   Downloading tqdm-4.52.0-py2.py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 6.3 MB/s
# Requirement already satisfied: pyzmq==22.0.3 in /opt/conda/lib/python3.7/site-packages (from greykite) (22.0.3)
# Collecting Sphinx==3.2.1
#   Downloading Sphinx-3.2.1-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 24.9 MB/s
# Collecting sphinx-gallery==0.6.1
#   Downloading sphinx-gallery-0.6.1.tar.gz (107 kB)
#      |████████████████████████████████| 107 kB 32.1 MB/s
# Collecting sphinx-rtd-theme==0.4.2
#   Downloading sphinx_rtd_theme-0.4.2-py2.py3-none-any.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 25.8 MB/s
# Requirement already satisfied: scikit-learn==0.24.1 in /opt/conda/lib/python3.7/site-packages (from greykite) (0.24.1)
# Collecting tornado==5.1.1
#   Downloading tornado-5.1.1.tar.gz (516 kB)
#      |████████████████████████████████| 516 kB 24.7 MB/s
# Requirement already satisfied: six==1.15.0 in /opt/conda/lib/python3.7/site-packages (from greykite) (1.15.0)
# Collecting cvxpy==1.1.12
#   Downloading cvxpy-1.1.12.tar.gz (1.3 MB)
#      |████████████████████████████████| 1.3 MB 26.5 MB/s
# done
#   Getting requirements to build wheel ... done
# done
# Requirement already satisfied: Cython==0.29.23 in /opt/conda/lib/python3.7/site-packages (from greykite) (0.29.23)
# Collecting numpy==1.20.2
#   Downloading numpy-1.20.2-cp37-cp37m-manylinux2010_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 662 kB/s
# Requirement already satisfied: jupyter-core==4.7.1 in /opt/conda/lib/python3.7/site-packages (from greykite) (4.7.1)
# Requirement already satisfied: patsy==0.5.1 in /opt/conda/lib/python3.7/site-packages (from greykite) (0.5.1)
# Requirement already satisfied: statsmodels==0.12.2 in /opt/conda/lib/python3.7/site-packages (from greykite) (0.12.2)
# Collecting nbformat==5.1.3
#   Downloading nbformat-5.1.3-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 25.0 MB/s
# Collecting overrides==2.8.0
#   Downloading overrides-2.8.0.tar.gz (4.5 kB)
# Collecting notebook==5.4.1
#   Downloading notebook-5.4.1-py2.py3-none-any.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 29.2 MB/s
# Collecting ipywidgets==7.2.1
#   Downloading ipywidgets-7.2.1-py2.py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 30.9 MB/s
# Requirement already satisfied: scs>=1.1.6 in /opt/conda/lib/python3.7/site-packages (from cvxpy==1.1.12->greykite) (2.1.3)
# Requirement already satisfied: ecos>=2 in /opt/conda/lib/python3.7/site-packages (from cvxpy==1.1.12->greykite) (2.0.7.post1)
# Collecting lunardate>=0.1.5
#   Downloading lunardate-0.2.0-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: convertdate>=2.1.2 in /opt/conda/lib/python3.7/site-packages (from fbprophet==0.5->greykite) (2.3.2)
# Requirement already satisfied: setuptools-git>=1.2 in /opt/conda/lib/python3.7/site-packages (from fbprophet==0.5->greykite) (1.2)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.7/site-packages (from holidays==0.9.10->greykite) (2.8.1)
# Requirement already satisfied: traitlets>=4.1.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel==4.8.2->greykite) (5.0.5)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython==7.1.1->greykite) (4.4.2)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from ipython==7.1.1->greykite) (2.8.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython==7.1.1->greykite) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.7/site-packages (from ipython==7.1.1->greykite) (49.6.0.post20210108)
# Collecting prompt-toolkit<2.1.0,>=2.0.0
#   Downloading prompt_toolkit-2.0.10-py3-none-any.whl (340 kB)
#      |████████████████████████████████| 340 kB 26.7 MB/s
# Requirement already satisfied: pexpect in /opt/conda/lib/python3.7/site-packages (from ipython==7.1.1->greykite) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /opt/conda/lib/python3.7/site-packages (from ipython==7.1.1->greykite) (0.18.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython==7.1.1->greykite) (0.7.5)
# Collecting widgetsnbextension~=3.2.0
#   Downloading widgetsnbextension-3.2.1-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 25.8 MB/s
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.7/site-packages (from jupyter==1.0.0->greykite) (6.0.7)
# Requirement already satisfied: qtconsole in /opt/conda/lib/python3.7/site-packages (from jupyter==1.0.0->greykite) (5.0.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib==3.4.1->greykite) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib==3.4.1->greykite) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib==3.4.1->greykite) (0.10.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat==5.1.3->greykite) (3.2.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from nbformat==5.1.3->greykite) (0.2.0)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.7/site-packages (from notebook==5.4.1->greykite) (1.5.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from notebook==5.4.1->greykite) (2.11.3)
# Requirement already satisfied: terminado>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from notebook==5.4.1->greykite) (0.9.3)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from osqp==0.6.1->greykite) (0.18.2)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas==1.1.3->greykite) (2021.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from plotly==3.10.0->greykite) (2.25.1)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from plotly==3.10.0->greykite) (1.3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.24.1->greykite) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.24.1->greykite) (1.0.1)
# Collecting sphinxcontrib-htmlhelp
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 6.1 MB/s
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 5.8 MB/s
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.1.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.3 MB/s
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 25.2 MB/s
# Collecting sphinxcontrib-serializinghtml
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 1.8 MB/s
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: docutils>=0.12 in /opt/conda/lib/python3.7/site-packages (from Sphinx==3.2.1->greykite) (0.17.1)
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.4 MB/s
# Collecting imagesize
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Requirement already satisfied: babel>=1.3 in /opt/conda/lib/python3.7/site-packages (from Sphinx==3.2.1->greykite) (2.9.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from Sphinx==3.2.1->greykite) (20.9)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /opt/conda/lib/python3.7/site-packages (from convertdate>=2.1.2->fbprophet==0.5->greykite) (0.5.11)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.10->ipython==7.1.1->greykite) (0.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->notebook==5.4.1->greykite) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==5.1.3->greykite) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==5.1.3->greykite) (20.3.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==5.1.3->greykite) (3.4.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython==7.1.1->greykite) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->plotly==3.10.0->greykite) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->plotly==3.10.0->greykite) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->plotly==3.10.0->greykite) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->plotly==3.10.0->greykite) (2.10)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.7/site-packages (from terminado>=0.8.1->notebook==5.4.1->greykite) (0.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat==5.1.3->greykite) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat==5.1.3->greykite) (3.4.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->greykite) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->greykite) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->greykite) (1.4.2)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->greykite) (0.1.2)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->greykite) (0.4.4)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->greykite) (3.3.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->greykite) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter==1.0.0->greykite) (0.8.4)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter==1.0.0->greykite) (1.4.3)
# Requirement already satisfied: async-generator in /opt/conda/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter==1.0.0->greykite) (1.10)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->jupyter==1.0.0->greykite) (0.5.1)
# Requirement already satisfied: qtpy in /opt/conda/lib/python3.7/site-packages (from qtconsole->jupyter==1.0.0->greykite) (1.9.0)
# Building wheels for collected packages: cvxpy, fbprophet, holidays, overrides, sphinx-gallery, tornado
# done
#   Created wheel for cvxpy: filename=cvxpy-1.1.12-cp37-cp37m-linux_x86_64.whl size=2733193 sha256=ac4322c1314448bd9b796a5bd01c667af4639b71e0459f9aed39072e5df54677
#   Stored in directory: /root/.cache/pip/wheels/0c/c5/a5/bd7a06743cd4504096d9690d8c3e1ac21dfaec5b222aa6cb39
# done
#   Created wheel for fbprophet: filename=fbprophet-0.5-py3-none-any.whl size=6613578 sha256=31830ea6ff289709c110a97fece6ac4b73024ea3fa9f3aeb35ea6244e7a8ca2d
#   Stored in directory: /root/.cache/pip/wheels/67/b1/ca/ad24f4ff43720362a231c594483f97498af99b40fe264cd056
# done
#   Created wheel for holidays: filename=holidays-0.9.10-py3-none-any.whl size=40246 sha256=8ca0af4dc366d5b605cb79fc1361e791fb940180f2e2cbed2e0f89502d3f6b86
#   Stored in directory: /root/.cache/pip/wheels/21/cd/85/72012ab03b64e6a571847d758881c0170b701e1d88d646eeff
# done
#   Created wheel for overrides: filename=overrides-2.8.0-py3-none-any.whl size=5607 sha256=66a2df81b7e3660036ca9cac33a92fe0d002b3b43cda83c1cc1a49a83d99f965
#   Stored in directory: /root/.cache/pip/wheels/ac/34/8c/cea535228b1cebb4ee9c3ddc82fe0fa955dbae5e4e25d51457
# done
#   Created wheel for sphinx-gallery: filename=sphinx_gallery-0.6.1-py3-none-any.whl size=107349 sha256=9bd52fcc9b471f30da9f85871fd21951eabfab24c5f30bf9031489b4cd237123
#   Stored in directory: /root/.cache/pip/wheels/9b/fe/73/c185c97254b2be70edd1850d1a19da4bcfb69de3282937db96
# done
#   Created wheel for tornado: filename=tornado-5.1.1-cp37-cp37m-linux_x86_64.whl size=463350 sha256=24eae09f512d317ebc772b422253e643d9c577806189bcee0faa6c99561eccd9
#   Stored in directory: /root/.cache/pip/wheels/83/91/4b/ee8ffb993d3372fc4129c52c9140792c118dda0373b41e7a8f
# Successfully built cvxpy fbprophet holidays overrides sphinx-gallery tornado
# Installing collected packages: tornado, prompt-toolkit, nbformat, jupyter-client, ipython, ipykernel, numpy, notebook, widgetsnbextension, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, Pillow, imagesize, alabaster, Sphinx, pystan, pandas, osqp, lunardate, jupyter-console, ipywidgets, holidays, tqdm, testfixtures, sphinx-rtd-theme, sphinx-gallery, seaborn, plotly, overrides, jupyter, fbprophet, cvxpy, greykite
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.18
#     Uninstalling prompt-toolkit-3.0.18:
#       Successfully uninstalled prompt-toolkit-3.0.18
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.1.2
#     Uninstalling nbformat-5.1.2:
#       Successfully uninstalled nbformat-5.1.2
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.22.0
#     Uninstalling ipython-7.22.0:
#       Successfully uninstalled ipython-7.22.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.0
#     Uninstalling ipykernel-5.5.0:
#       Successfully uninstalled ipykernel-5.5.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.3.0
#     Uninstalling notebook-6.3.0:
#       Successfully uninstalled notebook-6.3.0
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.5.1
#     Uninstalling widgetsnbextension-3.5.1:
#       Successfully uninstalled widgetsnbextension-3.5.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.2.0
#     Uninstalling Pillow-7.2.0:
#       Successfully uninstalled Pillow-7.2.0
#   Attempting uninstall: pystan
#     Found existing installation: pystan 2.19.1.1
#     Uninstalling pystan-2.19.1.1:
#       Successfully uninstalled pystan-2.19.1.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.3
#     Uninstalling pandas-1.2.3:
#       Successfully uninstalled pandas-1.2.3
#   Attempting uninstall: osqp
#     Found existing installation: osqp 0.6.2.post0
#     Uninstalling osqp-0.6.2.post0:
#       Successfully uninstalled osqp-0.6.2.post0
#   Attempting uninstall: jupyter-console
#     Found existing installation: jupyter-console 6.4.0
#     Uninstalling jupyter-console-6.4.0:
#       Successfully uninstalled jupyter-console-6.4.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.3
#     Uninstalling ipywidgets-7.6.3:
#       Successfully uninstalled ipywidgets-7.6.3
#   Attempting uninstall: holidays
#     Found existing installation: holidays 0.11.1
#     Uninstalling holidays-0.11.1:
#       Successfully uninstalled holidays-0.11.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.59.0
#     Uninstalling tqdm-4.59.0:
#       Successfully uninstalled tqdm-4.59.0
#   Attempting uninstall: sphinx-rtd-theme
#     Found existing installation: sphinx-rtd-theme 0.2.4
#     Uninstalling sphinx-rtd-theme-0.2.4:
#       Successfully uninstalled sphinx-rtd-theme-0.2.4
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.1
#     Uninstalling seaborn-0.11.1:
#       Successfully uninstalled seaborn-0.11.1
#   Attempting uninstall: plotly
#     Found existing installation: plotly 4.14.3
#     Uninstalling plotly-4.14.3:
#       Successfully uninstalled plotly-4.14.3
#   Attempting uninstall: overrides
#     Found existing installation: overrides 3.1.0
#     Uninstalling overrides-3.1.0:
#       Successfully uninstalled overrides-3.1.0
#   Attempting uninstall: fbprophet
#     Found existing installation: fbprophet 0.7.1
#     Uninstalling fbprophet-0.7.1:
#       Successfully uninstalled fbprophet-0.7.1
#   Attempting uninstall: cvxpy
#     Found existing installation: cvxpy 1.1.7
#     Uninstalling cvxpy-1.1.7:
#       Successfully uninstalled cvxpy-1.1.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.20.2 which is incompatible.
# tensorflow 2.4.1 requires numpy~=1.19.2, but you have numpy 1.20.2 which is incompatible.
# sklearn-pandas 2.1.0 requires pandas>=1.1.4, but you have pandas 1.1.3 which is incompatible.
# pyldavis 3.3.1 requires pandas>=1.2.0, but you have pandas 1.1.3 which is incompatible.
# preprocessing 0.1.13 requires sphinx-rtd-theme==0.2.4, but you have sphinx-rtd-theme 0.4.2 which is incompatible.
# plotly-express 0.4.1 requires plotly>=4.1.0, but you have plotly 3.10.0 which is incompatible.
# pdpbox 0.2.1 requires matplotlib==3.1.1, but you have matplotlib 3.4.1 which is incompatible.
# pandas-profiling 2.11.0 requires ipywidgets>=7.5.1, but you have ipywidgets 7.2.1 which is incompatible.
# pandas-profiling 2.11.0 requires seaborn>=0.10.1, but you have seaborn 0.9.0 which is incompatible.
# matrixprofile 1.1.10 requires protobuf==3.11.2, but you have protobuf 3.15.8 which is incompatible.
# jupyterlab-git 0.11.0 requires nbdime<2.0.0,>=1.1.0, but you have nbdime 2.1.0 which is incompatible.
# ipympl 0.7.0 requires ipywidgets>=7.6.0, but you have ipywidgets 7.2.1 which is incompatible.
# gym 0.18.0 requires Pillow<=7.2.0, but you have pillow 8.0.1 which is incompatible.
# cufflinks 0.17.3 requires plotly>=4.1.1, but you have plotly 3.10.0 which is incompatible.
# caip-notebooks-serverextension 1.0.0 requires ipywidgets>=7.5.1, but you have ipywidgets 7.2.1 which is incompatible.
# bqplot 0.12.25 requires ipywidgets>=7.5.0, but you have ipywidgets 7.2.1 which is incompatible.
# autogluon-core 0.1.0 requires numpy==1.19.5, but you have numpy 1.20.2 which is incompatible.
# allennlp 2.3.0 requires overrides==3.1.0, but you have overrides 2.8.0 which is incompatible.
# Successfully installed Pillow-8.0.1 Sphinx-3.2.1 alabaster-0.7.12 cvxpy-1.1.12 fbprophet-0.5 greykite-0.1.1 holidays-0.9.10 imagesize-1.2.0 ipykernel-4.8.2 ipython-7.1.1 ipywidgets-7.2.1 jupyter-1.0.0 jupyter-client-6.1.5 jupyter-console-6.0.0 lunardate-0.2.0 nbformat-5.1.3 notebook-5.4.1 numpy-1.20.2 osqp-0.6.1 overrides-2.8.0 pandas-1.1.3 plotly-3.10.0 prompt-toolkit-2.0.10 pystan-2.18.0.0 seaborn-0.9.0 snowballstemmer-2.1.0 sphinx-gallery-0.6.1 sphinx-rtd-theme-0.4.2 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5 testfixtures-6.14.2 tornado-5.1.1 tqdm-4.52.0 widgetsnbextension-3.2.1

# %%
# !pip install pillow==4.1.1
# %reload_ext autoreload
# %autoreload
# Out:
# Collecting pillow==4.1.1
#   Downloading Pillow-4.1.1.tar.gz (11.3 MB)
#      |████████████████████████████████| 11.3 MB 5.4 MB/s
# Requirement already satisfied: olefile in /opt/conda/lib/python3.7/site-packages (from pillow==4.1.1) (0.46)
# Building wheels for collected packages: pillow
# done
#   Created wheel for pillow: filename=Pillow-4.1.1-cp37-cp37m-linux_x86_64.whl size=1256700 sha256=d618e888fb7a06eca0ad6fb274f07c08eaa7429afb60ed569b68afe584d4d8e4
#   Stored in directory: /root/.cache/pip/wheels/51/53/67/d76ff9fd54dd89a25efce20d2e7c9b35348db386b53deb8095
# Successfully built pillow
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.0.1
#     Uninstalling Pillow-8.0.1:
#       Successfully uninstalled Pillow-8.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-image 0.18.1 requires pillow!=7.1.0,!=7.1.1,>=4.3.0, but you have pillow 4.1.1 which is incompatible.
# matplotlib 3.4.1 requires pillow>=6.2.0, but you have pillow 4.1.1 which is incompatible.
# ipympl 0.7.0 requires ipywidgets>=7.6.0, but you have ipywidgets 7.2.1 which is incompatible.
# greykite 0.1.1 requires Pillow==8.0.1, but you have pillow 4.1.1 which is incompatible.
# fury 0.7.0 requires pillow>=5.4.1, but you have pillow 4.1.1 which is incompatible.
# fastai 2.3.0 requires pillow>6.0.0, but you have pillow 4.1.1 which is incompatible.
# bokeh 2.3.1 requires pillow>=7.1.0, but you have pillow 4.1.1 which is incompatible.
# autogluon-core 0.1.0 requires numpy==1.19.5, but you have numpy 1.20.2 which is incompatible.
# allennlp 2.3.0 requires overrides==3.1.0, but you have overrides 2.8.0 which is incompatible.
# Successfully installed pillow-4.1.1

# %%
# !pip install --force-reinstall pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 4.9 MB/s
# Collecting pytz>=2017.3
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 6.3 MB/s
# Collecting numpy>=1.16.5
#   Downloading numpy-1.20.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 11.5 MB/s
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 14.0 MB/s
# Collecting six>=1.5
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, pytz, python-dateutil, numpy, pandas
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.1
#     Uninstalling pytz-2021.1:
#       Successfully uninstalled pytz-2021.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
#       Successfully uninstalled python-dateutil-2.8.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.2
#     Uninstalling numpy-1.20.2:
#       Successfully uninstalled numpy-1.20.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.3
#     Uninstalling pandas-1.1.3:
#       Successfully uninstalled pandas-1.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.20.3 which is incompatible.
# tensorflow 2.4.1 requires numpy~=1.19.2, but you have numpy 1.20.3 which is incompatible.
# tensorflow 2.4.1 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# scikit-image 0.18.1 requires pillow!=7.1.0,!=7.1.1,>=4.3.0, but you have pillow 4.1.1 which is incompatible.
# plotly-express 0.4.1 requires plotly>=4.1.0, but you have plotly 3.10.0 which is incompatible.
# pdpbox 0.2.1 requires matplotlib==3.1.1, but you have matplotlib 3.4.1 which is incompatible.
# pandas-profiling 2.11.0 requires ipywidgets>=7.5.1, but you have ipywidgets 7.2.1 which is incompatible.
# pandas-profiling 2.11.0 requires seaborn>=0.10.1, but you have seaborn 0.9.0 which is incompatible.
# matrixprofile 1.1.10 requires protobuf==3.11.2, but you have protobuf 3.15.8 which is incompatible.
# matplotlib 3.4.1 requires pillow>=6.2.0, but you have pillow 4.1.1 which is incompatible.
# jupyterlab-git 0.11.0 requires nbdime<2.0.0,>=1.1.0, but you have nbdime 2.1.0 which is incompatible.
# ipympl 0.7.0 requires ipywidgets>=7.6.0, but you have ipywidgets 7.2.1 which is incompatible.
# greykite 0.1.1 requires numpy==1.20.2, but you have numpy 1.20.3 which is incompatible.
# greykite 0.1.1 requires pandas==1.1.3, but you have pandas 1.2.4 which is incompatible.
# greykite 0.1.1 requires Pillow==8.0.1, but you have pillow 4.1.1 which is incompatible.
# greykite 0.1.1 requires six==1.15.0, but you have six 1.16.0 which is incompatible.
# fury 0.7.0 requires pillow>=5.4.1, but you have pillow 4.1.1 which is incompatible.
# fastai 2.3.0 requires pillow>6.0.0, but you have pillow 4.1.1 which is incompatible.
# earthengine-api 0.1.261 requires google-api-python-client<2,>=1.12.1, but you have google-api-python-client 1.8.0 which is incompatible.
# cufflinks 0.17.3 requires plotly>=4.1.1, but you have plotly 3.10.0 which is incompatible.
# caip-notebooks-serverextension 1.0.0 requires ipywidgets>=7.5.1, but you have ipywidgets 7.2.1 which is incompatible.
# bqplot 0.12.25 requires ipywidgets>=7.5.0, but you have ipywidgets 7.2.1 which is incompatible.
# bokeh 2.3.1 requires pillow>=7.1.0, but you have pillow 4.1.1 which is incompatible.
# autogluon-core 0.1.0 requires numpy==1.19.5, but you have numpy 1.20.3 which is incompatible.
# allennlp 2.3.0 requires overrides==3.1.0, but you have overrides 2.8.0 which is incompatible.
# aiobotocore 1.3.0 requires botocore<1.20.50,>=1.20.49, but you have botocore 1.20.53 which is incompatible.
# Successfully installed numpy-1.20.3 pandas-1.2.4 python-dateutil-2.8.1 pytz-2021.1 six-1.16.0

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold">✅ Importing the required Libraries :</h1>

# %%
from collections import defaultdict
import warnings
import pandas as pd
warnings.filterwarnings("ignore")
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt 
import datetime, pytz
from plotly import tools
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import gc
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import plotly
from sklearn.metrics import mean_absolute_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Activation
import keras
import tensorflow
from greykite.framework.templates.autogen.forecast_config import ForecastConfig
from greykite.framework.templates.autogen.forecast_config import MetadataParam
from greykite.framework.templates.forecaster import Forecaster 
from greykite.framework.templates.model_templates import ModelTemplateEnum
from greykite.framework.utils.result_summary import summarize_grid_search_results
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold"> 🛠 Data Preprocessing :</h1>

# %%
df = pd.read_csv('../input/bitcoin-historical-data/bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv')
df['date'] = pd.to_datetime(df['Timestamp'],unit='s').dt.date
group = df.groupby('date')
Price = group['Weighted_Price'].mean()

# %%
df_price_zz=Price.to_frame()
df_price_zz['Timestamp'] = df_price_zz.index
df_price_zz['Timestamp'] = pd.to_datetime(df_price_zz['Timestamp'])
df_price_zz.reset_index(drop=True,inplace=True)
df_price_include_zz = df_price_zz[df_price_zz['Timestamp'].dt.year >= 2017]
df_price_include_zz.reset_index(drop=True,inplace=True)
# df_price_include_zz

# %%
df_price_include_zz.set_index("Timestamp", inplace = True)
df_price_include_zz
# Out:
#             Weighted_Price
# Timestamp
# 2017-01-01      981.637688
# 2017-01-02     1013.199484
# 2017-01-03     1019.992995
# 2017-01-04     1079.434027
# 2017-01-05     1039.655397
# ...                    ...
# 2021-03-27    55193.357260
# 2021-03-28    55832.958824
# 2021-03-29    56913.993819
# 2021-03-30    58346.912268
# 2021-03-31    58764.349363
#
# [1551 rows x 1 columns]

# %%
Price.to_numpy()
df_price=Price.to_frame()
df_price['Timestamp'] = df_price.index
df_price['Timestamp'] = pd.to_datetime(df_price['Timestamp'])
df_price.reset_index(drop=True,inplace=True)
df_price_include = df_price[df_price['Timestamp'].dt.year >= 2017]
df_price_include.reset_index(drop=True,inplace=True)

# %%
prediction_days = 50
df_train= df_price_include_zz[:len(df_price_include_zz)-prediction_days]
df_test= df_price_include_zz[len(df_price_include_zz)-prediction_days:]

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold"> Creating a Forecast :</h1>

# %% [markdown]
# <p style="font-size:15px;color:#1C37A6;">The forecast can be created with just a few lines of code. First, specify the dataset information. We are setting the time_col parameter as 'Timestamp' and the value_col parameter as 'Weighted_Price'. In freq, we are setting value as D for Daily at the start date. After this create a forecaster using the Forecaster class from the GreyKite package. The output of run_forecast_config() would be a dictionary which is having future predicted values, original time series, and historical forecast performance</p>

# %%
metadata = MetadataParam(
 time_col="Timestamp",   # ----> name of the time column 
 value_col="Weighted_Price",  # ----> name of the value column 
 freq="W"           #"MS" for Montly at start date, "H" for hourly, "D" for daily, "W" for weekly, etc.
)

# %%
forecaster = Forecaster()
result = forecaster.run_forecast_config(
     df=df_price_include,
     config=ForecastConfig(
         model_template=ModelTemplateEnum.SILVERKITE.name,
         forecast_horizon=30,  # forecasts 30 steps ahead
         coverage=0.95,  # 95% prediction intervals
         metadata_param=metadata
    )
)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits

# %%
fig = result.timeseries.plot()
fig.show()
# Out:
# <div>
#
#
#             <div id="7470c8af-3bac-4a64-943b-3bcd812382df" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7470c8af-3bac-4a64-943b-3bcd812382df")) {
#                     Plotly.newPlot(
#                         '7470c8af-3bac-4a64-943b-3bcd812382df',
#                         [{"line": {"color": "rgb(32, 149, 212)"}, "mode": "lines", "name": "Weighted_Price", "opacity": 0.8, "type": "scatter", "uid": "9b9629e0-aabf-4022-9a3c-77a9b6e751a9", "x": ["2017-01-01", "2017-01-08", "2017-01-15", "2017-01-22", "2017-01-29", "2017-02-05", "2017-02-12", "2017-02-19", "2017-02-26", "2017-03-05", "2017-03-12", "2017-03-19", "2017-03-26", "2017-04-02", "2017-04-09", "2017-04-16", "2017-04-23", "2017-04-30", "2017-05-07", "2017-05-14", "2017-05-21", "2017-05-28", "2017-06-04", "2017-06-11", "2017-06-18", "2017-06-25", "2017-07-02", "2017-07-09", "2017-07-16", "2017-07-23", "2017-07-30", "2017-08-06", "2017-08-13", "2017-08-20", "2017-08-27", "2017-09-03", "2017-09-10", "2017-09-17", "2017-09-24", "2017-10-01", "2017-10-08", "2017-10-15", "2017-10-22", "2017-10-29", "2017-11-05", "2017-11-12", "2017-11-19", "2017-11-26", "2017-12-03", "2017-12-10", "2017-12-17", "2017-12-24", "2017-12-31", "2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "2018-04-22", "2018-04-29", "2018-05-06", "2018-05-13", "2018-05-20", "2018-05-27", "2018-06-03", "2018-06-10", "2018-06-17", "2018-06-24", "2018-07-01", "2018-07-08", "2018-07-15", "2018-07-22", "2018-07-29", "2018-08-05", "2018-08-12", "2018-08-19", "2018-08-26", "2018-09-02", "2018-09-09", "2018-09-16", "2018-09-23", "2018-09-30", "2018-10-07", "2018-10-14", "2018-10-21", "2018-10-28", "2018-11-04", "2018-11-11", "2018-11-18", "2018-11-25", "2018-12-02", "2018-12-09", "2018-12-16", "2018-12-23", "2018-12-30", "2019-01-06", "2019-01-13", "2019-01-20", "2019-01-27", "2019-02-03", "2019-02-10", "2019-02-17", "2019-02-24", "2019-03-03", "2019-03-10", "2019-03-17", "2019-03-24", "2019-03-31", "2019-04-07", "2019-04-14", "2019-04-21", "2019-04-28", "2019-05-05", "2019-05-12", "2019-05-19", "2019-05-26", "2019-06-02", "2019-06-09", "2019-06-16", "2019-06-23", "2019-06-30", "2019-07-07", "2019-07-14", "2019-07-21", "2019-07-28", "2019-08-04", "2019-08-11", "2019-08-18", "2019-08-25", "2019-09-01", "2019-09-08", "2019-09-15", "2019-09-22", "2019-09-29", "2019-10-06", "2019-10-13", "2019-10-20", "2019-10-27", "2019-11-03", "2019-11-10", "2019-11-17", "2019-11-24", "2019-12-01", "2019-12-08", "2019-12-15", "2019-12-22", "2019-12-29", "2020-01-05", "2020-01-12", "2020-01-19", "2020-01-26", "2020-02-02", "2020-02-09", "2020-02-16", "2020-02-23", "2020-03-01", "2020-03-08", "2020-03-15", "2020-03-22", "2020-03-29", "2020-04-05", "2020-04-12", "2020-04-19", "2020-04-26", "2020-05-03", "2020-05-10", "2020-05-17", "2020-05-24", "2020-05-31", "2020-06-07", "2020-06-14", "2020-06-21", "2020-06-28", "2020-07-05", "2020-07-12", "2020-07-19", "2020-07-26", "2020-08-02", "2020-08-09", "2020-08-16", "2020-08-23", "2020-08-30", "2020-09-06", "2020-09-13", "2020-09-20", "2020-09-27", "2020-10-04", "2020-10-11", "2020-10-18", "2020-10-25", "2020-11-01", "2020-11-08", "2020-11-15", "2020-11-22", "2020-11-29", "2020-12-06", "2020-12-13", "2020-12-20", "2020-12-27", "2021-01-03", "2021-01-10", "2021-01-17", "2021-01-24", "2021-01-31", "2021-02-07", "2021-02-14", "2021-02-21", "2021-02-28", "2021-03-07", "2021-03-14", "2021-03-21", "2021-03-28"], "y": [981.6376879920928, 915.2058142519436, 817.0549635712492, 921.0022294154238, 916.4743844403482, 1018.327562124935, 1002.9858857063558, 1052.5456970824382, 1165.8244162493393, 1258.6520904332842, 1198.4495991848353, 1009.8453678806043, 965.6647718384512, 1080.593671156791, 1195.2263193941758, 1168.5849291604588, 1235.959071154503, 1331.428636861853, 1541.9670501659964, 1781.992960291066, 2022.2277678510666, 2188.8339780159095, 2524.769903107526, 2907.1849046281804, 2564.159564217592, 2557.9534132747376, 2445.2220216764304, 2538.7765526156186, 1938.9989240757789, 2766.018589895212, 2674.9081195927315, 3236.1315535456533, 4022.9411932688417, 4059.5180476308906, 4340.433891081189, 457 ...

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold">Cross-Validation :</h1>

# %% [markdown]
# <p style="font-size:15px;color:#1C37A6;">As a matter of course, run_forecast_config gives chronicled assessment, so you can perceive how the conjecture performs on past information. This is put away in grid_search (cross-approval parts) and backtest (holdout test set).</p>

# %%
grid_search = result.grid_search
cv_results = summarize_grid_search_results(
     grid_search=grid_search,
     decimals=2,
     # The below saves space in the printed output. Remove to show all available metrics and columns.
     cv_report_metrics=None,
     column_order=["rank", "mean_test", "split_test", "mean_train", "split_train", "mean_fit_time", "mean_score_time", "params"])
 # Transposes to save space in the printed output
cv_results["params"] = cv_results["params"].astype(str)
cv_results.set_index("params", drop=True, inplace=True)
cv_results.transpose()
# Out:
# params                               []
# rank_test_MAPE                        1
# mean_test_MAPE                    61.08
# split_test_MAPE   (119.69, 34.5, 29.04)
# mean_train_MAPE                   74.34
# split_train_MAPE  (25.57, 101.05, 96.4)
# mean_fit_time                     10.36
# mean_score_time                    0.88

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold">Backtest :</h1>

# %%
backtest = result.backtest
fig = backtest.plot().show()
# Out:
# <div>
#
#
#             <div id="5c76656e-c2f3-44bc-a5c4-c25d9a04b630" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5c76656e-c2f3-44bc-a5c4-c25d9a04b630")) {
#                     Plotly.newPlot(
#                         '5c76656e-c2f3-44bc-a5c4-c25d9a04b630',
#                         [{"legendgroup": "interval", "line": {"color": "rgba(0, 90, 181, 0.5)", "width": 0.0}, "mode": "lines", "name": "Lower Bound", "type": "scatter", "uid": "41705c46-01b1-4b7a-a097-3eed0f47cd02", "x": ["2017-01-01", "2017-01-08", "2017-01-15", "2017-01-22", "2017-01-29", "2017-02-05", "2017-02-12", "2017-02-19", "2017-02-26", "2017-03-05", "2017-03-12", "2017-03-19", "2017-03-26", "2017-04-02", "2017-04-09", "2017-04-16", "2017-04-23", "2017-04-30", "2017-05-07", "2017-05-14", "2017-05-21", "2017-05-28", "2017-06-04", "2017-06-11", "2017-06-18", "2017-06-25", "2017-07-02", "2017-07-09", "2017-07-16", "2017-07-23", "2017-07-30", "2017-08-06", "2017-08-13", "2017-08-20", "2017-08-27", "2017-09-03", "2017-09-10", "2017-09-17", "2017-09-24", "2017-10-01", "2017-10-08", "2017-10-15", "2017-10-22", "2017-10-29", "2017-11-05", "2017-11-12", "2017-11-19", "2017-11-26", "2017-12-03", "2017-12-10", "2017-12-17", "2017-12-24", "2017-12-31", "2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "2018-04-22", "2018-04-29", "2018-05-06", "2018-05-13", "2018-05-20", "2018-05-27", "2018-06-03", "2018-06-10", "2018-06-17", "2018-06-24", "2018-07-01", "2018-07-08", "2018-07-15", "2018-07-22", "2018-07-29", "2018-08-05", "2018-08-12", "2018-08-19", "2018-08-26", "2018-09-02", "2018-09-09", "2018-09-16", "2018-09-23", "2018-09-30", "2018-10-07", "2018-10-14", "2018-10-21", "2018-10-28", "2018-11-04", "2018-11-11", "2018-11-18", "2018-11-25", "2018-12-02", "2018-12-09", "2018-12-16", "2018-12-23", "2018-12-30", "2019-01-06", "2019-01-13", "2019-01-20", "2019-01-27", "2019-02-03", "2019-02-10", "2019-02-17", "2019-02-24", "2019-03-03", "2019-03-10", "2019-03-17", "2019-03-24", "2019-03-31", "2019-04-07", "2019-04-14", "2019-04-21", "2019-04-28", "2019-05-05", "2019-05-12", "2019-05-19", "2019-05-26", "2019-06-02", "2019-06-09", "2019-06-16", "2019-06-23", "2019-06-30", "2019-07-07", "2019-07-14", "2019-07-21", "2019-07-28", "2019-08-04", "2019-08-11", "2019-08-18", "2019-08-25", "2019-09-01", "2019-09-08", "2019-09-15", "2019-09-22", "2019-09-29", "2019-10-06", "2019-10-13", "2019-10-20", "2019-10-27", "2019-11-03", "2019-11-10", "2019-11-17", "2019-11-24", "2019-12-01", "2019-12-08", "2019-12-15", "2019-12-22", "2019-12-29", "2020-01-05", "2020-01-12", "2020-01-19", "2020-01-26", "2020-02-02", "2020-02-09", "2020-02-16", "2020-02-23", "2020-03-01", "2020-03-08", "2020-03-15", "2020-03-22", "2020-03-29", "2020-04-05", "2020-04-12", "2020-04-19", "2020-04-26", "2020-05-03", "2020-05-10", "2020-05-17", "2020-05-24", "2020-05-31", "2020-06-07", "2020-06-14", "2020-06-21", "2020-06-28", "2020-07-05", "2020-07-12", "2020-07-19", "2020-07-26", "2020-08-02", "2020-08-09", "2020-08-16", "2020-08-23", "2020-08-30", "2020-09-06", "2020-09-13", "2020-09-20", "2020-09-27", "2020-10-04", "2020-10-11", "2020-10-18", "2020-10-25", "2020-11-01", "2020-11-08", "2020-11-15", "2020-11-22", "2020-11-29", "2020-12-06", "2020-12-13", "2020-12-20", "2020-12-27", "2021-01-03", "2021-01-10", "2021-01-17", "2021-01-24", "2021-01-31", "2021-02-07", "2021-02-14", "2021-02-21", "2021-02-28", "2021-03-07", "2021-03-14", "2021-03-21", "2021-03-28"], "y": [-719.9981308343858, -537.8494947855279, -595.1073061373509, -767.1881881956515, -905.9752870957391, -870.6358094395055, -869.6896127647551, -699.6502983177807, -689.9153673686333, -669.5806446641045, -1133.1901226228256, -1202.4131320258894, -1359.2278819215298, -1344.905645452618, -1156.6277014819834, -1092.2794473795202, -845.720797570294, -666.5390645308371, -458.00162428377917, -330.7456412298334, -257.43693458496546, -301.14426782075134, -164.06184485953963, -286.74809197274135, -177.65856911231003, -148.06620887449662, -149.57828586908818, -35.49196369144738, -127.49059040636803, -15.00090665137759, 231.3807032887662, 403.91420583572835, 371.323549 ...

# %%
backtest_eval = defaultdict(list)
for metric, value in backtest.train_evaluation.items():
    backtest_eval[metric].append(value)
    backtest_eval[metric].append(backtest.test_evaluation[metric])
metrics = pd.DataFrame(backtest_eval, index=["train", "test"]).T
metrics
# Out:
#                                                              train  \
# CORR                                                      0.594936
# R2                                                        0.290326
# MSE                                                 8220000.077316
# RMSE                                                   2867.054251
# MAE                                                    2218.427776
# MedAE                                                   1993.22315
# MAPE                                                     66.119362
# MedAPE                                                   25.144316
# sMAPE                                                    19.925027
# Q80                                                    1109.213888
# Q95                                                    1109.213888
# Q99                                                    1109.213888
# OutsideTolerance1p                                        0.958333
# OutsideTolerance2p                                          0.9375
# OutsideTolerance3p                                        0.932292
# OutsideTolerance4p                                         0.90625
# OutsideTolerance5p                                        0.890625
# Outside Tolerance (fraction)                                  None
# R2_null_model_score                                           None
# Prediction Band Width (%)                               274.513915
# Prediction Band Coverage (fraction)                       0.958333
# Coverage: Lower Band                                      0.515625
# Coverage: Upper Band                                      0.442708
# Coverage Diff: Actual_Coverage - Intended_Coverage        0.008333
#
#                                                                 test
# CORR                                                       -0.214846
# R2                                                         -1.358032
# MSE                                                 651840627.084136
# RMSE                                                    25531.169716
# MAE                                                     19311.124468
# MedAE                                                   11812.747633
# MAPE                                                       54.895566
# MedAPE                                                      55.25163
# sMAPE                                                      41.851798
# Q80                                                     15448.899574
# Q95                                                     18345.568245
# Q99                                                     19118.013223
# OutsideTolerance1p                                               1.0
# OutsideTolerance2p                                               1.0
# OutsideTolerance3p                                               1.0
# OutsideTolerance4p                                               1.0
# OutsideTolerance5p                                               1.0
# Outside Tolerance (fraction)                                    None
# R2_null_model_score                                             None
# Prediction Band Width (%)                                  57.179494
# Prediction Band Coverage (fraction)                              0.3
# Coverage: Lower Band                                             0.0
# Coverage: Upper Band                                             0.3
# Coverage Diff: Actual_Coverage - Intended_Coverage             -0.65

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold">Forecast :</h1>

# %%
forecast = result.forecast
fig = forecast.plot().show()
# Out:
# <div>
#
#
#             <div id="9b8a8d3d-2e1c-4d25-9099-cedb1e05ded6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9b8a8d3d-2e1c-4d25-9099-cedb1e05ded6")) {
#                     Plotly.newPlot(
#                         '9b8a8d3d-2e1c-4d25-9099-cedb1e05ded6',
#                         [{"legendgroup": "interval", "line": {"color": "rgba(0, 90, 181, 0.5)", "width": 0.0}, "mode": "lines", "name": "Lower Bound", "type": "scatter", "uid": "1695deee-f3bf-43f4-90a2-fd4276462e32", "x": ["2017-01-01", "2017-01-08", "2017-01-15", "2017-01-22", "2017-01-29", "2017-02-05", "2017-02-12", "2017-02-19", "2017-02-26", "2017-03-05", "2017-03-12", "2017-03-19", "2017-03-26", "2017-04-02", "2017-04-09", "2017-04-16", "2017-04-23", "2017-04-30", "2017-05-07", "2017-05-14", "2017-05-21", "2017-05-28", "2017-06-04", "2017-06-11", "2017-06-18", "2017-06-25", "2017-07-02", "2017-07-09", "2017-07-16", "2017-07-23", "2017-07-30", "2017-08-06", "2017-08-13", "2017-08-20", "2017-08-27", "2017-09-03", "2017-09-10", "2017-09-17", "2017-09-24", "2017-10-01", "2017-10-08", "2017-10-15", "2017-10-22", "2017-10-29", "2017-11-05", "2017-11-12", "2017-11-19", "2017-11-26", "2017-12-03", "2017-12-10", "2017-12-17", "2017-12-24", "2017-12-31", "2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "2018-04-22", "2018-04-29", "2018-05-06", "2018-05-13", "2018-05-20", "2018-05-27", "2018-06-03", "2018-06-10", "2018-06-17", "2018-06-24", "2018-07-01", "2018-07-08", "2018-07-15", "2018-07-22", "2018-07-29", "2018-08-05", "2018-08-12", "2018-08-19", "2018-08-26", "2018-09-02", "2018-09-09", "2018-09-16", "2018-09-23", "2018-09-30", "2018-10-07", "2018-10-14", "2018-10-21", "2018-10-28", "2018-11-04", "2018-11-11", "2018-11-18", "2018-11-25", "2018-12-02", "2018-12-09", "2018-12-16", "2018-12-23", "2018-12-30", "2019-01-06", "2019-01-13", "2019-01-20", "2019-01-27", "2019-02-03", "2019-02-10", "2019-02-17", "2019-02-24", "2019-03-03", "2019-03-10", "2019-03-17", "2019-03-24", "2019-03-31", "2019-04-07", "2019-04-14", "2019-04-21", "2019-04-28", "2019-05-05", "2019-05-12", "2019-05-19", "2019-05-26", "2019-06-02", "2019-06-09", "2019-06-16", "2019-06-23", "2019-06-30", "2019-07-07", "2019-07-14", "2019-07-21", "2019-07-28", "2019-08-04", "2019-08-11", "2019-08-18", "2019-08-25", "2019-09-01", "2019-09-08", "2019-09-15", "2019-09-22", "2019-09-29", "2019-10-06", "2019-10-13", "2019-10-20", "2019-10-27", "2019-11-03", "2019-11-10", "2019-11-17", "2019-11-24", "2019-12-01", "2019-12-08", "2019-12-15", "2019-12-22", "2019-12-29", "2020-01-05", "2020-01-12", "2020-01-19", "2020-01-26", "2020-02-02", "2020-02-09", "2020-02-16", "2020-02-23", "2020-03-01", "2020-03-08", "2020-03-15", "2020-03-22", "2020-03-29", "2020-04-05", "2020-04-12", "2020-04-19", "2020-04-26", "2020-05-03", "2020-05-10", "2020-05-17", "2020-05-24", "2020-05-31", "2020-06-07", "2020-06-14", "2020-06-21", "2020-06-28", "2020-07-05", "2020-07-12", "2020-07-19", "2020-07-26", "2020-08-02", "2020-08-09", "2020-08-16", "2020-08-23", "2020-08-30", "2020-09-06", "2020-09-13", "2020-09-20", "2020-09-27", "2020-10-04", "2020-10-11", "2020-10-18", "2020-10-25", "2020-11-01", "2020-11-08", "2020-11-15", "2020-11-22", "2020-11-29", "2020-12-06", "2020-12-13", "2020-12-20", "2020-12-27", "2021-01-03", "2021-01-10", "2021-01-17", "2021-01-24", "2021-01-31", "2021-02-07", "2021-02-14", "2021-02-21", "2021-02-28", "2021-03-07", "2021-03-14", "2021-03-21", "2021-03-28", "2021-04-04", "2021-04-11", "2021-04-18", "2021-04-25", "2021-05-02", "2021-05-09", "2021-05-16", "2021-05-23", "2021-05-30", "2021-06-06", "2021-06-13", "2021-06-20", "2021-06-27", "2021-07-04", "2021-07-11", "2021-07-18", "2021-07-25", "2021-08-01", "2021-08-08", "2021-08-15", "2021-08-22", "2021-08-29", "2021-09-05", "2021-09-12", "2021-09-19", "2021-09-26", "2021-10-03", "2021-10-10", "2021-10-17", "2021-10-24"], "y": [-11440.625395527004, -11022.956611318827, -10947.510218459076, -11277.161245996374, -11360.55786308475, -11090.471391364132, -10413.597481020226, -9863.439466989406, -10044.557350924199, -10257.215270401864, -9899.969059130177, -9472.28435813 ...

# %%
forecast.df.head().round(2)
# Out:
#    Timestamp  actual  forecast  forecast_lower  forecast_upper
# 0 2017-01-01  981.64   5161.43       -11440.63        21763.49
# 1 2017-01-08  915.21   5579.10       -11022.96        22181.16
# 2 2017-01-15  817.05   5654.55       -10947.51        22256.61
# 3 2017-01-22  921.00   5324.90       -11277.16        21926.96
# 4 2017-01-29  916.47   5241.50       -11360.56        21843.56

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold">Model Diagnostics :</h1>

# %% [markdown]
#  <p style="font-size:15px;color:#1C37A6;"> This plot shows how your dataset’s trend, event/holiday, seasonality patterns are handled in the model.</p>

# %%
fig = forecast.plot_components().show()
# Out:
# <div>
#
#
#             <div id="d2a0480f-7ec8-4692-b602-d935a175f243" class="plotly-graph-div" style="height:2100px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d2a0480f-7ec8-4692-b602-d935a175f243")) {
#                     Plotly.newPlot(
#                         'd2a0480f-7ec8-4692-b602-d935a175f243',
#                         [{"mode": "lines", "name": "y", "opacity": 0.8, "showlegend": false, "type": "scatter", "uid": "b1815bb5-bc2b-4f00-94c0-9608037dec77", "x": ["2017-01-01", "2017-01-08", "2017-01-15", "2017-01-22", "2017-01-29", "2017-02-05", "2017-02-12", "2017-02-19", "2017-02-26", "2017-03-05", "2017-03-12", "2017-03-19", "2017-03-26", "2017-04-02", "2017-04-09", "2017-04-16", "2017-04-23", "2017-04-30", "2017-05-07", "2017-05-14", "2017-05-21", "2017-05-28", "2017-06-04", "2017-06-11", "2017-06-18", "2017-06-25", "2017-07-02", "2017-07-09", "2017-07-16", "2017-07-23", "2017-07-30", "2017-08-06", "2017-08-13", "2017-08-20", "2017-08-27", "2017-09-03", "2017-09-10", "2017-09-17", "2017-09-24", "2017-10-01", "2017-10-08", "2017-10-15", "2017-10-22", "2017-10-29", "2017-11-05", "2017-11-12", "2017-11-19", "2017-11-26", "2017-12-03", "2017-12-10", "2017-12-17", "2017-12-24", "2017-12-31", "2018-01-07", "2018-01-14", "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-18", "2018-02-25", "2018-03-04", "2018-03-11", "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "2018-04-22", "2018-04-29", "2018-05-06", "2018-05-13", "2018-05-20", "2018-05-27", "2018-06-03", "2018-06-10", "2018-06-17", "2018-06-24", "2018-07-01", "2018-07-08", "2018-07-15", "2018-07-22", "2018-07-29", "2018-08-05", "2018-08-12", "2018-08-19", "2018-08-26", "2018-09-02", "2018-09-09", "2018-09-16", "2018-09-23", "2018-09-30", "2018-10-07", "2018-10-14", "2018-10-21", "2018-10-28", "2018-11-04", "2018-11-11", "2018-11-18", "2018-11-25", "2018-12-02", "2018-12-09", "2018-12-16", "2018-12-23", "2018-12-30", "2019-01-06", "2019-01-13", "2019-01-20", "2019-01-27", "2019-02-03", "2019-02-10", "2019-02-17", "2019-02-24", "2019-03-03", "2019-03-10", "2019-03-17", "2019-03-24", "2019-03-31", "2019-04-07", "2019-04-14", "2019-04-21", "2019-04-28", "2019-05-05", "2019-05-12", "2019-05-19", "2019-05-26", "2019-06-02", "2019-06-09", "2019-06-16", "2019-06-23", "2019-06-30", "2019-07-07", "2019-07-14", "2019-07-21", "2019-07-28", "2019-08-04", "2019-08-11", "2019-08-18", "2019-08-25", "2019-09-01", "2019-09-08", "2019-09-15", "2019-09-22", "2019-09-29", "2019-10-06", "2019-10-13", "2019-10-20", "2019-10-27", "2019-11-03", "2019-11-10", "2019-11-17", "2019-11-24", "2019-12-01", "2019-12-08", "2019-12-15", "2019-12-22", "2019-12-29", "2020-01-05", "2020-01-12", "2020-01-19", "2020-01-26", "2020-02-02", "2020-02-09", "2020-02-16", "2020-02-23", "2020-03-01", "2020-03-08", "2020-03-15", "2020-03-22", "2020-03-29", "2020-04-05", "2020-04-12", "2020-04-19", "2020-04-26", "2020-05-03", "2020-05-10", "2020-05-17", "2020-05-24", "2020-05-31", "2020-06-07", "2020-06-14", "2020-06-21", "2020-06-28", "2020-07-05", "2020-07-12", "2020-07-19", "2020-07-26", "2020-08-02", "2020-08-09", "2020-08-16", "2020-08-23", "2020-08-30", "2020-09-06", "2020-09-13", "2020-09-20", "2020-09-27", "2020-10-04", "2020-10-11", "2020-10-18", "2020-10-25", "2020-11-01", "2020-11-08", "2020-11-15", "2020-11-22", "2020-11-29", "2020-12-06", "2020-12-13", "2020-12-20", "2020-12-27", "2021-01-03", "2021-01-10", "2021-01-17", "2021-01-24", "2021-01-31", "2021-02-07", "2021-02-14", "2021-02-21", "2021-02-28", "2021-03-07", "2021-03-14", "2021-03-21", "2021-03-28"], "xaxis": "x", "y": [981.6376879920928, 915.2058142519436, 817.0549635712492, 921.0022294154238, 916.4743844403482, 1018.327562124935, 1002.9858857063558, 1052.5456970824382, 1165.8244162493393, 1258.6520904332842, 1198.4495991848353, 1009.8453678806043, 965.6647718384512, 1080.593671156791, 1195.2263193941758, 1168.5849291604588, 1235.959071154503, 1331.428636861853, 1541.9670501659964, 1781.992960291066, 2022.2277678510666, 2188.8339780159095, 2524.769903107526, 2907.1849046281804, 2564.159564217592, 2557.9534132747376, 2445.2220216764304, 2538.7765526156186, 1938.9989240757789, 2766.018589895212, 2674.9081195927315, 3236.1315535456533, 4022.9411932688417, 4059.5180476308906, 4340.433891081189, 4575.300758474094, 41 ...

# %% [markdown]
#  <p style="font-size:15px;color:#1C37A6;"> The model summary allows inspection of individual model terms. Check parameter estimates and their significance for insights on how the model works and what can be further improved.</p>

# %%
summary = result.model[-1].summary()  # -1 retrieves the estimator from the pipeline
print(summary)
# Out:
# ================================ Model Summary =================================
#
# Number of observations: 222,   Number of features: 101
# Method: Ridge regression
# Number of nonzero features: 72
# Regularization parameter: 376.5
#
# Residuals:
#          Min           1Q       Median           3Q          Max
#      -8495.0      -3627.0      -2059.0       -21.37    4.445e+04
#
#             Pred_col Estimate Std. Err Pr(>)_boot sig. code             95%CI
#            Intercept   4769.0    368.1     <2e-16       ***  (4166.0, 5631.0)
#  events_C...New Year       0.       0.      1.000                    (0., 0.)
#  events_C...w Year-1       0.       0.      1.000                    (0., 0.)
#  events_C...w Year-2   -17.32     16.2      0.130                (-53.89, 0.)
#  events_C...w Year+1   -21.04    14.51      0.096         .      (-54.25, 0.)
#  events_C...w Year+2     92.1     78.1      0.094         .       (0., 259.2)
# events_Christmas Day       0.       0.      1.000                    (0., 0.)
#  events_C...as Day-1    15.86     14.8      0.158                 (0., 48.97)
#  events_C...as Day-2   -15.87    14.37      0.152                (-47.89, 0.)
#  events_C...as Day+1       0.       0.      1.000                    (0., 0.)
#  events_C...as Day+2    33.04     30.6      0.484                 (0., 101.6)
#  events_E...Ireland]       0.       0.      1.000                    (0., 0.)
#  events_E...eland]-1   -31.13    16.13      0.042         * (-65.24, -0.2075)
#  events_E...eland]-2       0.       0.      1.000                    (0., 0.)
#  events_E...eland]+1       0.       0.      1.000                    (0., 0.)
#  events_E...eland]+2       0.       0.      1.000                    (0., 0.)
#   events_Good Friday       0.       0.      1.000                    (0., 0.)
# events_Good Friday-1       0.       0.      1.000                    (0., 0.)
# events_Good Friday-2       0.       0.      1.000                    (0., 0.)
# events_Good Friday+1       0.       0.      1.000                    (0., 0.)
# events_Good Friday+2   -31.13    16.13      0.042         * (-65.24, -0.2075)
#  events_I...ence Day       0.       0.      1.000                    (0., 0.)
#  events_I...ce Day-1       0.       0.      1.000                    (0., 0.)
#  events_I...ce Day-2   -12.51    8.936      0.098         .      (-33.83, 0.)
#  events_I...ce Day+1   -10.85    9.371      0.152             (-32.53, 0.823)
#  events_I...ce Day+2       0.       0.      1.000                    (0., 0.)
#     events_Labor Day       0.       0.      1.000                    (0., 0.)
#   events_Labor Day-1   -24.27    11.88      0.028         *  (-48.47, -4.018)
#   events_Labor Day-2    6.173    5.641      0.164                 (0., 19.41)
#   events_Labor Day+1       0.       0.      1.000                    (0., 0.)
#   events_Labor Day+2   -6.972    5.916      0.128                (-20.14, 0.)
#  events_Memorial Day       0.       0.      1.000                    (0., 0.)
#  events_M...al Day-1   -20.47    11.68      0.062         .   (-46.95, -1.04)
#  events_M...al Day-2       0.       0.      1.000                    (0., 0.)
#  events_M...al Day+1       0.       0.      1.000                    (0., 0.)
#  events_M...al Day+2       0.       0.      1.000                    (0., 0.)
# events_New Years Day    -11.1     10.7      0.154                (-36.49, 0.)
#  events_N...rs Day-1    15.29    13.67      0.148                 (0., 46.32)
#  events_N...rs Day-2    -16.0    14.54      0.160                 (-45.9, 0.)
#  events_N...rs Day+1       0.       0.      1.000                    (0., 0.)
#  events_N...rs Day+2    50.38    41.25      0.104                 (0., 136.8)
#         events_Other   -60.19    94.23      0.542             (-214.5, 128.5)
#       events_Other-1   -37.28    105.9      0.736             (-236.5, 175.4)
#       events_Other-2    -34.4     58.2      0.568              (-136.2, 86.6)
#       events_Other+1    26.78    57.69      0.640             (-91.12, 135.9)
#       events_Other+2   -4.034    59.48      0.938             (-114.1, 118.1)
#  events_Thanksgiving       0.       0.      1.000                    (0., 0.)
#  events_T...giving-1       0.       0.      1.000                    (0., 0.)
#  events_T...giving-2       0.       0.      1.000                    (0., 0.)
#  events_T...giving+1       0.       0.      1.000                    (0., 0.)
#  events_T...giving+2       0.       0.      1.000                    (0., 0.)
#  events_Veterans Day   -6.308    5.879      0.148                 (-19.0, 0.)
#  events_V...ns Day-1   -5.502    5.498      0.118                (-17.23, 0.)
#  events_V...ns Day-2       0.       0.      1.000                    (0., 0.)
#  events_V...ns Day+1   -1.254    2.074      0.636            (-7.071, 0.3866)
#  events_V...ns Day+2       0.       0.      1.000                    (0., 0.)
#                  ct1   2286.0    332.7     <2e-16       ***  (1614.0, 2866.0)
#     sin1_tom_monthly    -37.5    122.7      0.778             (-277.5, 198.8)
#     cos1_tom_monthly   -37.96    119.9      0.734             (-269.3, 209.1)
#     sin2_tom_monthly   -18.02    177.0      0.924             (-341.4, 301.9)
#     cos2_tom_monthly    -30.0    191.0      0.888             (-416.7, 319.8)
#   sin1_toq_quarterly   -183.8    134.3      0.172             (-472.6, 65.46)
#   cos1_toq_quarterly    -20.8    144.0      0.860             (-273.7, 281.3)
#   sin2_toq_quarterly   -61.17    133.2      0.636             (-307.9, 208.6)
#   cos2_toq_quarterly    27.82    139.8      0.846             (-265.8, 305.4)
#   sin3_toq_quarterly   -36.48    123.4      0.782             (-271.5, 195.8)
#   cos3_toq_quarterly   -39.61    121.6      0.728             (-276.8, 201.7)
#   sin4_toq_quarterly   -9.204    196.3      0.952             (-359.9, 421.0)
#   cos4_toq_quarterly   -12.81    170.3      0.938             (-365.9, 317.1)
#   sin5_toq_quarterly   -61.66    181.6      0.728             (-403.4, 317.7)
#   cos5_toq_quarterly   -25.51    184.1      0.852             (-373.8, 358.1)
#      sin1_ct1_yearly    370.3    190.4      0.040         *    (17.32, 743.8)
#      cos1_ct1_yearly    609.8    136.5     <2e-16       ***    (339.9, 841.1)
#      sin2_ct1_yearly    434.1    168.6      0.012         *    (98.94, 768.4)
#      cos2_ct1_yearly    77.84    167.8      0.662             (-269.9, 385.9)
#      sin3_ct1_yearly   -2.741    163.9      0.984             (-324.2, 311.5)
#      cos3_ct1_yearly   -203.2    174.9      0.254             (-546.5, 120.3)
#      sin4_ct1_yearly   -181.7    136.2      0.180             (-480.1, 66.11)
#      cos4_ct1_yearly   -37.41    142.0      0.780             (-285.7, 258.3)
#      sin5_ct1_yearly   -45.57    165.5      0.778             (-360.1, 276.9)
#      cos5_ct1_yearly    217.1    180.7      0.242             (-111.2, 568.8)
#      sin6_ct1_yearly    105.8    186.6      0.550             (-269.7, 481.2)
#      cos6_ct1_yearly    114.7    156.7      0.470             (-193.3, 412.2)
#      sin7_ct1_yearly    32.64    161.3      0.850             (-277.6, 336.5)
#      cos7_ct1_yearly   -44.67    168.3      0.752             (-354.0, 314.8)
#      sin8_ct1_yearly   -60.03    132.6      0.644             (-304.6, 200.4)
#      cos8_ct1_yearly     12.5    140.0      0.944             (-281.2, 282.7)
#      sin9_ct1_yearly    24.07    184.8      0.898             (-316.5, 382.8)
#      cos9_ct1_yearly    76.31    155.1      0.600             (-244.1, 362.2)
#     sin10_ct1_yearly    124.7    173.1      0.462             (-213.4, 476.2)
#     cos10_ct1_yearly    16.04    175.1      0.920             (-299.7, 361.1)
#     sin11_ct1_yearly    69.91    173.7      0.668             (-264.1, 420.4)
#     cos11_ct1_yearly   -114.5    180.6      0.518             (-486.8, 223.7)
#     sin12_ct1_yearly   -29.66    126.3      0.834             (-255.7, 201.4)
#     cos12_ct1_yearly   -54.31    121.2      0.636             (-289.9, 176.5)
#     sin13_ct1_yearly   -43.21    168.6      0.784             (-423.3, 269.5)
#     cos13_ct1_yearly    9.842    171.3      0.930             (-332.9, 328.0)
#     sin14_ct1_yearly    33.38    167.3      0.836             (-288.8, 357.4)
#     cos14_ct1_yearly    26.72    178.9      0.884             (-311.4, 396.1)
#     sin15_ct1_yearly    31.61    167.7      0.862             (-285.8, 357.3)
#     cos15_ct1_yearly   -28.84    193.5      0.884             (-352.2, 333.6)
# Signif. Code: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Multiple R-squared: 0.2942,   Adjusted R-squared: 0.2624
# F-statistic: 2.709 on 9 and 211 DF,   p-value: 0.004446
# Model AIC: 5235.1,   model BIC: 5270.9
#
# WARNING: the F-ratio and its p-value on regularized methods might be misleading, they are provided only for reference purposes.
# WARNING: the following columns have estimated coefficients equal to zero, while ridge is not supposed to have zero estimates. This is probably because these columns are degenerate in the design matrix. Make sure these columns do not have constant values.
# ["C(Q('events_Chinese New Year'), levels=['', 'event'])[T.event]", "C(Q('events_Chinese New Year_minus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Christmas Day'), levels=['', 'event'])[T.event]", "C(Q('events_Christmas Day_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Easter Monday [England, Wales, Northern Ireland]'), levels=['', 'event'])[T.event]", "C(Q('events_Easter Monday [England, Wales, Northern Ireland]_minus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Easter Monday [England, Wales, Northern Ireland]_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Easter Monday [England, Wales, Northern Ireland]_plus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Good Friday'), levels=['', 'event'])[T.event]", "C(Q('events_Good Friday_minus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Good Friday_minus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Good Friday_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Independence Day'), levels=['', 'event'])[T.event]", "C(Q('events_Independence Day_minus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Independence Day_plus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Labor Day'), levels=['', 'event'])[T.event]", "C(Q('events_Labor Day_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Memorial Day'), levels=['', 'event'])[T.event]", "C(Q('events_Memorial Day_minus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Memorial Day_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Memorial Day_plus_2'), levels=['', 'event'])[T.event]", "C(Q('events_New Years Day_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Thanksgiving'), levels=['', 'event'])[T.event]", "C(Q('events_Thanksgiving_minus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Thanksgiving_minus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Thanksgiving_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Thanksgiving_plus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Veterans Day_minus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Veterans Day_plus_2'), levels=['', 'event'])[T.event]"]
# WARNING: the following columns are degenerate, do you really want to include them in your model? This may cause some of them to show unrealistic significance. Consider using the `drop_degenerate` transformer.
# ['Intercept', "C(Q('events_Chinese New Year'), levels=['', 'event'])[T.event]", "C(Q('events_Chinese New Year_minus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Christmas Day'), levels=['', 'event'])[T.event]", "C(Q('events_Christmas Day_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Easter Monday [England, Wales, Northern Ireland]'), levels=['', 'event'])[T.event]", "C(Q('events_Easter Monday [England, Wales, Northern Ireland]_minus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Easter Monday [England, Wales, Northern Ireland]_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Easter Monday [England, Wales, Northern Ireland]_plus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Good Friday'), levels=['', 'event'])[T.event]", "C(Q('events_Good Friday_minus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Good Friday_minus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Good Friday_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Independence Day'), levels=['', 'event'])[T.event]", "C(Q('events_Independence Day_minus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Independence Day_plus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Labor Day'), levels=['', 'event'])[T.event]", "C(Q('events_Labor Day_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Memorial Day'), levels=['', 'event'])[T.event]", "C(Q('events_Memorial Day_minus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Memorial Day_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Memorial Day_plus_2'), levels=['', 'event'])[T.event]", "C(Q('events_New Years Day_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Thanksgiving'), levels=['', 'event'])[T.event]", "C(Q('events_Thanksgiving_minus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Thanksgiving_minus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Thanksgiving_plus_1'), levels=['', 'event'])[T.event]", "C(Q('events_Thanksgiving_plus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Veterans Day_minus_2'), levels=['', 'event'])[T.event]", "C(Q('events_Veterans Day_plus_2'), levels=['', 'event'])[T.event]"]

# %%
model = result.model
model
# Out:
# Pipeline(steps=[('input',
#                  PandasFeatureUnion(transformer_list=[('date',
#                                                        Pipeline(steps=[('select_date',
#                                                                         ColumnSelector(column_names=['ts']))])),
#                                                       ('response',
#                                                        Pipeline(steps=[('select_val',
#                                                                         ColumnSelector(column_names=['y'])),
#                                                                        ('outlier',
#                                                                         ZscoreOutlierTransformer()),
#                                                                        ('null',
#                                                                         NullTransformer(impute_algorithm='interpolate',
#                                                                                         impute_params={'axis': 0,
#                                                                                                        'limit_direct...
#                                                             'simple_freq': <SimpleTimeFrequencyEnum.WEEK: Frequency(default_horizon=12, seconds_per_observation=604800, valid_seas={'YEARLY_SEASONALITY', 'QUARTERLY_SEASONALITY', 'MONTHLY_SEASONALITY'})>,
#                                                             'start_year': 2017},
#                                            uncertainty_dict={'params': {'conditional_cols': None,
#                                                                         'quantile_estimation_method': 'normal_fit',
#                                                                         'quantiles': [0.025000000000000022,
#                                                                                       0.975],
#                                                                         'sample_size_thresh': 5,
#                                                                         'small_sample_size_method': 'std_quantiles',
#                                                                         'small_sample_size_quantile': 0.98},
#                                                              'uncertainty_method': 'simple_conditional_residuals'}))])

# %%
future_df = result.timeseries.make_future_dataframe(
    periods=4,
    include_history=False)
future_df
# Out:
#                    ts   y
# 2021-04-04 2021-04-04 NaN
# 2021-04-11 2021-04-11 NaN
# 2021-04-18 2021-04-18 NaN
# 2021-04-25 2021-04-25 NaN

# %%
model.predict(future_df)
# Out:
#           ts      forecast  forecast_lower  forecast_upper  \
# 0 2021-04-04  13649.960702    -2952.099380    30252.020784
# 1 2021-04-11  13489.418170    -3112.641912    30091.478253
# 2 2021-04-18  13722.150936    -2879.909146    30324.211018
# 3 2021-04-25  13904.266001    -2697.794081    30506.326083
#
#                           y_quantile_summary
# 0   (-2952.099380335603, 30252.020784326283)
# 1  (-3112.6419118407503, 30091.478252821136)
# 2   (-2879.9091462868455, 30324.21101837504)
# 3    (-2697.794081232947, 30506.32608342894)

# %% [markdown]
# <h1 style="background-color:#88FBFF;font-size:30px;color:#00033E;font-weight : bold">LSTM approach :</h1>

# %% [markdown]
# ![](https://miro.medium.com/max/1032/1*AUwc53cmW04hjPrKtVyePQ.gif)

# %%
training_set = df_train.values
training_set = np.reshape(training_set, (len(training_set), 1))
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
training_set = sc.fit_transform(training_set)
X_train = training_set[0:len(training_set)-1]
y_train = training_set[1:len(training_set)]
X_train = np.reshape(X_train, (len(X_train), 1, 1))

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold">Training the Model :</h1>

# %%
model1 = Sequential()
model1.add(LSTM(10,activation="sigmoid",return_sequences = True,input_shape = (None, 1)))
# model1.add(Dropout(0.2))
# model1.add(LSTM(64,return_sequences = True))
# model1.add(Dropout(0.2))
# model1.add(LSTM(10))
# model1.add(Dropout(0.2))

model1.add(Dense(1))
model1.compile(loss='mean_squared_error', optimizer='adam')

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 10)          480
# _________________________________________________________________
# dense (Dense)                (None, None, 1)           11
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model1.fit(X_train, y_train, batch_size = 5, epochs = 20)
# Out:
# Epoch 1/20
# 300/300 [==============================] - 2s 1ms/step - loss: 0.0172
# Epoch 2/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.0152
# Epoch 3/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.0116
# Epoch 4/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.0100
# Epoch 5/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 6/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.0064
# Epoch 7/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.0048
# Epoch 8/20
# 300/300 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 9/20
# 300/300 [==============================] - 0s 1ms/step - loss: 9.8513e-04
# Epoch 10/20
# 300/300 [==============================] - 0s 1ms/step - loss: 4.2500e-04
# Epoch 11/20
# 300/300 [==============================] - 0s 1ms/step - loss: 1.9875e-04
# Epoch 12/20
# 300/300 [==============================] - 0s 2ms/step - loss: 1.3462e-04
# Epoch 13/20
# 300/300 [==============================] - 0s 1ms/step - loss: 1.1303e-04
# Epoch 14/20
# 300/300 [==============================] - 0s 1ms/step - loss: 1.5250e-04
# Epoch 15/20
# 300/300 [==============================] - 0s 1ms/step - loss: 9.9508e-05
# Epoch 16/20
# 300/300 [==============================] - 0s 1ms/step - loss: 1.3360e-04
# Epoch 17/20
# 300/300 [==============================] - 0s 1ms/step - loss: 1.2657e-04
# Epoch 18/20
# 300/300 [==============================] - 0s 1ms/step - loss: 1.1992e-04
# Epoch 19/20
# 300/300 [==============================] - 0s 1ms/step - loss: 9.3683e-05
# Epoch 20/20
# 300/300 [==============================] - 0s 1ms/step - loss: 1.3629e-04

# %% [markdown]
# <h1 style="background-color:#FF85A3;font-size:20px;color:#00033E;font-weight : bold">Visualizing Model Performance :</h1>

# %%
# %matplotlib inline
plt.figure(figsize=(15,5))
plt.plot(history.history['loss'])
plt.title("The model's evaluation", fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
from keras.utils.vis_utils import plot_model
plot_model(model1, to_file='model_plot.png', show_shapes=True, show_layer_names=True, expand_nested=False)

# %%
# Making the predictions
test_set = df_test.values
inputs = np.reshape(test_set, (len(test_set), 1))
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (len(inputs), 1, 1))
predicted_BTC_price = model1.predict(inputs)
predicted_BTC_price=predicted_BTC_price.reshape(-1,1)
predicted_BTC_price = sc.inverse_transform(predicted_BTC_price)

# %%
# %matplotlib inline
plt.figure(figsize=(15,8))
plt.plot(test_set, color = "red", label = "Real Stock Price")
plt.plot(predicted_BTC_price, color = "black", label = "Predict Stock Price")
plt.title("BTC Price Prediction")
plt.xlabel("Time")
plt.ylabel("BTC Price(USD)")
plt.legend()
plt.show()

# %% [markdown]
# <h1 style="background-color:#88FBFF;font-size:20px;color:#00033E;font-weight : bold">Wrapping Up :</h1>

# %% [markdown]
#  <p style="font-size:15px;color:#1C37A6;font-weight : bold">I had tried to give a gentle introduction to Time Series Forecasting Using GreyKite Python Library and the traditional LSTM approach. I hope you learn something from this blog, and it will help you in the future.<br>
# The library is still in the development process, and the developers are planning to add other useful open-source algorithms in the future to give users more options to choose from through a unified interface.</p>
#
# **References** :
# - https://engineering.linkedin.com/blog/2021/greykite--a-flexible--intuitive--and-fast-forecasting-library
# - https://arxiv.org/abs/2105.01098
# - https://venturebeat.com/2021/05/13/linkedin-open-sources-greykite-a-library-for-time-series-forecasting/
# - https://github.com/linkedin/greykite
# - https://analyticsindiamag.com/linkedin-open-sources-this-new-library-for-time-series-forecasting/

# %% [markdown]
# ![](https://i.pinimg.com/originals/cf/90/bb/cf90bb1b741ff44adde054a2e12b82e6.gif)

# %% [markdown]
# # **Do UPVOTE if you like my work**
